# %%
cd /Users/RichardP/research/fobos/py_FOBOS
# Out:
# /Users/RichardP/research/fobos/py_FOBOS

# %%
from hex_mask import hex_mask, fiber_centers

# %%
import numpy as np
from astropy.io import fits
from astropy import wcs
import matplotlib.pyplot as plt
import scipy.ndimage.filters as ndimage
#This is the specific code
import fobos_sim

# %%
gen = fobos_sim.fobos_sim('/Users/RichardP/Research/FOBOS/Samples/acs_I_030mas_088_sci.fits', .57, 7)
gen.catalog_info('/Users/RichardP/Research/FOBOS/Samples/photoz_vers2.0_010312_UltraVISTA2016.fits')

# %%
x0, y0 = gen.objects[1]

# %%
pixel_list, x1,y1, img, yy, xx = hex_mask(gen.scidata, x0, y0, 6, 7, plot = True)

# %%
for i in range(0, 7):
    plt.scatter(pixel_list['y'][str(i+1)], pixel_list['x'][str(i + 1)])
all_pixels = np.sum(len(pixel_list['x'][str(i+1)]) for i in range(0, 2)) 
print(all_pixels)
plt.gca().invert_yaxis()
plt.show()
# Out:
# 180

# %%
flux_sum = {}
for i in range(0, 7):
    flux_sum[str(i + 1)] = np.sum(gen.scidata[pixel_list['y'][str(i + 1)], pixel_list['x'][str(i + 1)]])
    print("Fiber_" + str(i + 1) + "_" + str(flux_sum[str(i + 1)]))
int_flux = np.sum(flux_sum[str(i + 1)] for i in range(0, 7))
print(int_flux)
# Out:
# Fiber_1_0.108609
# Fiber_2_0.0677841
# Fiber_3_0.0420905
# Fiber_4_0.0827869
# Fiber_5_0.115828
# Fiber_6_0.0954873
# Fiber_7_0.0383749
# 0.550960522145

# %%
pixel_list, x1,y1, img = hex_mask(gen.scidata, x0, y0, 13, 1, plot = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-0fadd84312cf> in <module>()
# ----> 1 pixel_list, x1,y1, img = hex_mask(gen.scidata, x0, y0, 13, 1, plot = True)
#
# ValueError: too many values to unpack (expected 4)

# %%
Flux_1= np.sum(gen.scidata[pixel_list['y'], pixel_list['x']])
print(Flux_1)

# %%
print(len(pixel_list['x']))

# %%
plt.scatter(pixel_list['x'], pixel_list['y'])
plt.show()

# %%
# Out:
# array([47, 48, 49, 49, 50, 50, 50, 49, 48, 47, 47, 46, 45, 45, 45, 45, 45,
#        45, 46, 47])
